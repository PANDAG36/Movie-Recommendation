# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("imdb_movies.csv")

a = df.columns

for i in a:
    print(f"{i} = {df[i].isnull().sum()}")

df["genre"] = df["genre"].replace( np.nan, "None")

df["crew"] = df["crew"].replace( np.nan, "None")

print("\n New Datasets \n")

for i in a:
    print(f"{i} = {df[i].isnull().sum()}")
# Out:
# names = 0
# date_x = 0
# score = 0
# genre = 85
# overview = 0
# crew = 56
# orig_title = 0
# status = 0
# orig_lang = 0
# budget_x = 0
# revenue = 0
# country = 0
#
#  New Datasets
#
# names = 0
# date_x = 0
# score = 0
# genre = 0
# overview = 0
# crew = 0
# orig_title = 0
# status = 0
# orig_lang = 0
# budget_x = 0
# revenue = 0
# country = 0

# %%
df[df["genre"].str.contains("None")]
# Out:
#                                        names       date_x  score genre  \
# 305         Housewife Sex Slaves: Hatano Yui  01/09/2015     0.0  None
# 1174                 Beauty Rope Cosmetology  12/02/1983    10.0  None
# 1561                                 Reclaim  07/29/2022    20.0  None
# 1762              Ancient Chinese Whorehouse  09/15/1994    50.0  None
# 1776       Porno document: Toruko tokkyû bin  02/26/1982   100.0  None
# ...                                      ...          ...    ...   ...
# 9626                                Euphoria  11/29/2022     0.0  None
# 9733                                 Fanatic  04/06/2023     0.0  None
# 10011                        Perfumed Garden  06/03/2000    53.0  None
# 10025  The Girl and the Wooden Horse Torture  12/03/1982    50.0  None
# 10076      The Shoga (Glass and Gas) Company  09/07/1990    37.0  None
#
#                                                 overview  \
# ...

# %%
df['genre'] = df['genre'].fillna('').str.replace("\xa0", " ").str.split(', ')

# %%
df["genre"]
# Out:
# 0                                          [Drama, Action]
# 1                     [Science Fiction, Adventure, Action]
# 2          [Animation, Adventure, Family, Fantasy, Comedy]
# 3          [Animation, Comedy, Family, Adventure, Fantasy]
# 4                                                 [Action]
#                                ...
# 10173                                              [Drama]
# 10174                                             [Action]
# 10175                           [Drama, Thriller, Romance]
# 10176    [Action, Adventure, Science Fiction, Thriller,...
# 10177                         [Animation, Family, Fantasy]
# Name: genre, Length: 10178, dtype: object

# %%
df = df.sort_values("score", ascending=False)

# %%
df.to_csv("cleaned_imdb_movies.csv")
